# %%
import requests
from bs4 import BeautifulSoup
from urllib.request import urlopen 
from urllib.error import URLError
import json
import pandas as pd
import re

# %%
def create_soup(link):
    '''Возвращает экземпляр BeautifulSoup для соответсвующей ссылки'''
    page = urlopen(link)
    html_bytes = page.read()
    html = html_bytes.decode("utf-8")
    return BeautifulSoup(html, "html.parser")

# %%
def process_page(vacancies, vac_dict):
    '''
    Обходит все вакансии на странице и добавляет извлеченные 
    данные в соотвествующий список
    '''
    # Создаем регулярное выражение для парсинга данных о ЗП
    regex = re.compile('vacancy-salary-compensation-type-.*')
    # Итерируем по списку вакансий
    for vacancy in vacancies:
        link = vacancy.find('a')['href']
        # Подготавливаем soup
        vac_soup = create_soup(link)
        # Извлекаем местоположение и отрасль
        try:
            js = json.loads("".join(vac_soup.find("script", {"type":"application/ld+json"}).contents))
            vac_dict['location'].append(js['jobLocation']['address']['addressLocality'])
            vac_dict['industry'].append(' '.join(js['industry']))
        except:
            continue
        # Извлекаем ЗП
        try:
            vac_dict['salary'].append(vac_soup.find('span', {'data-qa':regex}).get_text())   
        except:
            vac_dict['salary'].append(None)
        # Извлекаем нываки
        try:
            skills = vac_soup.findAll('div',{'data-qa':'bloko-tag bloko-tag_inline skills-element'})
            skil = [s.get_text() for s in skills]
            vac_dict['skills'].append(' '.join(skil)) 
        except:
            vac_dict['skills'].append(None)
        # Извлекаем опыт
        try:
            vac_dict['experience'].append(vac_soup.find('span',{'data-qa':'vacancy-experience'}).get_text())
        except: 
            vac_dict['experience'].append(None)

# %%
url = 'https://hh.ru/search/vacancy?area=113&search_field=description&only_with_salary=true&text=&hhtmFrom=vacancy_search_list'
vac_dict = {'location':[], 'industry':[], 'experience': [], 'skills':[], 'salary':[]}
pages = 40
# Итерируем по страницам
for page in range(pages):
    page_link = url + '&page=' + str(page)
    try:
        # Подготавливаем soup
        page_soup = create_soup(page_link)
        # Извлекаем все вакансии на странице
        vacancies = page_soup.find_all('div', class_='vacancy-serp-item-body')
        # Передаем полученный список в функцию для сбора данных о каждой вакансии
        process_page(vacancies, vac_dict)
    except:
        print('Произошла ошибка! Пропуск страницы...')
# Out:
# Произошла ошибка! Пропуск страницы...
# Произошла ошибка! Пропуск страницы...
# Произошла ошибка! Пропуск страницы...
# Произошла ошибка! Пропуск страницы...
# Произошла ошибка! Пропуск страницы...
# Произошла ошибка! Пропуск страницы...
# Произошла ошибка! Пропуск страницы...
# Произошла ошибка! Пропуск страницы...
# Произошла ошибка! Пропуск страницы...
# Произошла ошибка! Пропуск страницы...
# Произошла ошибка! Пропуск страницы...
# Произошла ошибка! Пропуск страницы...
# Произошла ошибка! Пропуск страницы...

# %%
# Преобразовываем словарь в DataFrame
vacancies = pd.DataFrame.from_dict(vac_dict)

# %%
# Записываем DataFrame в csv файл
vacancies.to_csv('vacancies.csv')

# %%
vacancies
# Out:
#            location                                           industry  \
# 0            Казань                               Транспорт, логистика
# 1           Воронеж                   Продажи Начало карьеры, студенты
# 2   Санкт-Петербург  Бухгалтерия, управленческий учет, финансы пред...
# 3      Электросталь                                            Продажи
# 4            Москва                   Производство, сельское хозяйство
# 5      Екатеринбург                                            Продажи
# 6       Владикавказ  Строительство, недвижимость Производство, сель...
# 7            Москва                       Автомобильный бизнес Продажи
# 8         Краснодар                                            Продажи
# 9            Москва                                            Продажи
# 10           Россия  Административный персонал Транспорт, логистика...
# 11           Россия  Административный персонал Транспорт, логистика...
# 12           Россия  Административный персонал Транспорт, логистика...
# 13           Москва                                            Продажи
# 14           Москва                    Управление персоналом, тренинги
# 15  Санкт-Петербург                               Транспорт, логистика
# 16      Владивосток                   Продажи Начало карьеры, студенты
# 17        Пятигорск                                            Продажи
# 18      Новосибирск  Инсталляция и сервис Информационные технологии...
# 19      Новосибирск                   Продажи Начало карьеры, студенты
# 20           Россия  Административный персонал Транспорт, логистика...
# 21  Санкт-Петербург  Бухгалтерия, управленческий учет, финансы пред...
# 22     Электросталь                                            Продажи
# 23           Москва                   Производство, сельское хозяйство
# 24     Екатеринбург                                            Продажи
# 25      Владикавказ  Строительство, недвижимость Производство, сель...
# 26           Москва                       Автомобильный бизнес Продажи
# 27        Краснодар                                            Продажи
# 28           Москва                                            Продажи
# 29           Россия  Административный персонал Транспорт, логистика...
# 30           Россия  Административный персонал Транспорт, логистика...
# 31           Россия  Административный персонал Транспорт, логистика...
# 32           Москва                                            Продажи
# 33           Москва                    Управление персоналом, тренинги
# 34  Санкт-Петербург                               Транспорт, логистика
# 35      Владивосток                   Продажи Начало карьеры, студенты
# 36            Тосно  Рабочий персонал Производство, сельское хозяйство
# 37           Москва       Рабочий персонал Строительство, недвижимость
# 38           Россия  Административный персонал Транспорт, логистика...
# 39  Санкт-Петербург  Бухгалтерия, управленческий учет, финансы пред...
# 40     Электросталь                                            Продажи
# 41           Москва                   Производство, сельское хозяйство
# 42     Екатеринбург                                            Продажи
# 43      Владикавказ  Строительство, недвижимость Производство, сель...
# 44           Москва                       Автомобильный бизнес Продажи
# 45        Краснодар                                            Продажи
# 46           Москва                                            Продажи
# 47           Россия  Административный персонал Транспорт, логистика...
# 48           Россия  Административный персонал Транспорт, логистика...
# 49           Россия  Административный персонал Транспорт, логистика...
# 50           Москва                                            Продажи
# 51           Москва                    Управление персоналом, тренинги
# 52  Санкт-Петербург                               Транспорт, логистика
# 53      Владивосток                   Продажи Начало карьеры, студенты
#
#       experience                                             skills  \
# 0       1–3 года  Опрятность Работать в команде Внимательность к...
# 1       1–3 года  Опыт продаж Ответственность и пунктуальность Ж...
# 2       1–3 года  Банк-клиент Первичная бухгалтерская документац...
# 3   не требуется  Телефонные переговоры B2C продажи CRM Навыки п...
# 4       1–3 года  Инициативность Ориентация на результат Коммуни...
# 5   не требуется
# 6        3–6 лет  Умение работать в команде строительно-монтажны...
# 7        3–6 лет  Навыки продаж Знание устройства автомобиля Пол...
# 8   не требуется                                   Активные продажи
# 9       1–3 года  телефонные продажи Холодные звонки входящие зв...
# 10      1–3 года  Грамотная речь Пользователь ПК Работа с больши...
# 11      1–3 года  Грамотная речь Пользователь ПК Работа с больши...
# 12      1–3 года  Грамотная речь Пользователь ПК Работа с больши...
# 13      1–3 года  Активные продажи Телефонные переговоры B2B Про...
# 14      1–3 года  Подбор персонала Работа в команде Креативность...
# 15  не требуется             Водительское удостоверение категории B
# 16  не требуется  Пользователь ПК Выкладка товаров Работа в кома...
# 17  не требуется  Пользователь ПК Прямые продажи Деловое общение...
# 18      1–3 года  Работа в команде Работа с электроинструментом ...
# 19  не требуется                          Умение работать в команде
# 20      1–3 года  Грамотная речь Пользователь ПК Работа с больши...
# 21      1–3 года  Банк-клиент Первичная бухгалтерская документац...
# 22  не требуется  Телефонные переговоры B2C продажи CRM Навыки п...
# 23      1–3 года  Инициативность Ориентация на результат Коммуни...
# 24  не требуется
# 25       3–6 лет  Умение работать в команде строительно-монтажны...
# 26       3–6 лет  Навыки продаж Знание устройства автомобиля Пол...
# 27  не требуется                                   Активные продажи
# 28      1–3 года  телефонные продажи Холодные звонки входящие зв...
# 29      1–3 года  Грамотная речь Пользователь ПК Работа с больши...
# 30      1–3 года  Грамотная речь Пользователь ПК Работа с больши...
# 31      1–3 года  Грамотная речь Пользователь ПК Работа с больши...
# 32      1–3 года  Активные продажи Телефонные переговоры B2B Про...
# 33      1–3 года  Подбор персонала Работа в команде Креативность...
# 34  не требуется             Водительское удостоверение категории B
# 35  не требуется  Пользователь ПК Выкладка товаров Работа в кома...
# 36  не требуется
# 37  не требуется  Физическая выносливость Добросовестное выполне...
# 38      1–3 года  Грамотная речь Пользователь ПК Работа с больши...
# 39      1–3 года  Банк-клиент Первичная бухгалтерская документац...
# 40  не требуется  Телефонные переговоры B2C продажи CRM Навыки п...
# 41      1–3 года  Инициативность Ориентация на результат Коммуни...
# 42  не требуется
# 43       3–6 лет  Умение работать в команде строительно-монтажны...
# 44       3–6 лет  Навыки продаж Знание устройства автомобиля Пол...
# 45  не требуется                                   Активные продажи
# 46      1–3 года  телефонные продажи Холодные звонки входящие зв...
# 47      1–3 года  Грамотная речь Пользователь ПК Работа с больши...
# 48      1–3 года  Грамотная речь Пользователь ПК Работа с больши...
# 49      1–3 года  Грамотная речь Пользователь ПК Работа с больши...
# 50      1–3 года  Активные продажи Телефонные переговоры B2B Про...
# 51      1–3 года  Подбор персонала Работа в команде Креативность...
# 52  не требуется             Водительское удостоверение категории B
# 53  не требуется  Пользователь ПК Выкладка товаров Работа в кома...
#
#                                         salary
# 0             от 50 000 до 50 000 руб. на руки
# 1             от 40 000 до 65 000 руб. на руки
# 2             от 50 000 до 60 000 руб. на руки
# 3                       от 70 000 руб. на руки
# 4                      от 160 000 руб. на руки
# 5             от 43 000 руб. до вычета налогов
# 6             от 50 000 до 60 000 руб. на руки
# 7           от 170 000 до 180 000 руб. на руки
# 8            от 50 000 до 150 000 руб. на руки
# 9                       от 80 000 руб. на руки
# 10            от 30 000 руб. до вычета налогов
# 11            от 30 000 руб. до вычета налогов
# 12            от 30 000 руб. до вычета налогов
# 13                      от 95 000 руб. на руки
# 14           от 70 000 до 120 000 руб. на руки
# 15           от 88 000 до 164 000 руб. на руки
# 16  от 48 000 до 55 000 руб. до вычета налогов
# 17            от 50 000 до 80 000 руб. на руки
# 18                      от 50 000 руб. на руки
# 19            от 46 900 руб. до вычета налогов
# 20            от 30 000 руб. до вычета налогов
# 21            от 50 000 до 60 000 руб. на руки
# 22                      от 70 000 руб. на руки
# 23                     от 160 000 руб. на руки
# 24            от 43 000 руб. до вычета налогов
# 25            от 50 000 до 60 000 руб. на руки
# 26          от 170 000 до 180 000 руб. на руки
# 27           от 50 000 до 150 000 руб. на руки
# 28                      от 80 000 руб. на руки
# 29            от 30 000 руб. до вычета налогов
# 30            от 30 000 руб. до вычета налогов
# 31            от 30 000 руб. до вычета налогов
# 32                      от 95 000 руб. на руки
# 33           от 70 000 до 120 000 руб. на руки
# 34           от 88 000 до 164 000 руб. на руки
# 35  от 48 000 до 55 000 руб. до вычета налогов
# 36            от 45 000 руб. до вычета налогов
# 37            от 60 000 до 90 000 руб. на руки
# 38            от 30 000 руб. до вычета налогов
# 39            от 50 000 до 60 000 руб. на руки
# 40                      от 70 000 руб. на руки
# 41                     от 160 000 руб. на руки
# 42            от 43 000 руб. до вычета налогов
# 43            от 50 000 до 60 000 руб. на руки
# 44          от 170 000 до 180 000 руб. на руки
# 45           от 50 000 до 150 000 руб. на руки
# 46                      от 80 000 руб. на руки
# 47            от 30 000 руб. до вычета налогов
# 48            от 30 000 руб. до вычета налогов
# 49            от 30 000 руб. до вычета налогов
# 50                      от 95 000 руб. на руки
# 51           от 70 000 до 120 000 руб. на руки
# 52           от 88 000 до 164 000 руб. на руки
# 53  от 48 000 до 55 000 руб. до вычета налогов
